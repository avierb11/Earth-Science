# %%
import matplotlib.pyplot as plt
import numpy as np
from FlowModel1D import FlowModel

# %% [markdown]
# # Initialize the model

# %%
mod = FlowModel()
mod.setDefaults()

# %% [markdown]
# ## Try some model stuff

# %%
mod.reset()
mod.flow(iters = 2000)
mod.plotHeads()

# %%
#mod.addMeasureConcentrationPoint(3)
#mod.addMeasureConcentrationPoint(5)
#mod.addMeasureConcentrationPoint(7)

mod.trackContaminantTransport(time=500)

# %%
mod.concentrations
# Out:
# array([-0.04986982, -0.00819647,  0.03505074,  0.07105817,  0.09772098,
#         0.11395556,  0.11979149,  0.11636191,  0.10570613,  0.08631361])
