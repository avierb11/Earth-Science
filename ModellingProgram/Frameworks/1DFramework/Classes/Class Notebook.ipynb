# %%
import numpy as np
import matplotlib.pyplot as plt
from ModelClass import *

# %%
mod = FlowModel()
mod.Groundwater.setDefaults()
mod.heads[0] = 1
mod.heads[-1] = 0

# %%
mod.flow(100)
mod.plotHeads()

# %%
print(mod.Data.flowPoints[0].data)
# Out:
# [3.1891742  2.4562502  1.7830952  1.2559756  0.8562868  0.56245106
#  0.3517559  0.20178732 0.09123277 0.00893086]
