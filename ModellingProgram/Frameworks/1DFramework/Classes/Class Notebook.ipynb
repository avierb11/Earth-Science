# %%
import numpy as np
import matplotlib.pyplot as plt
from ModelClass import *

# %%
mod = FlowModel(name="My first model")
mod.Groundwater.setDefaults()
mod.flow(iters = 150, track = True, step = 30)
mod.Grapher.plotFlowData()

# %%
mod2 = FlowModel(name="My second model")
mod2.Groundwater.setDefaults()
mod2.Groundwater.linearConductivityFit(start = .05, end = .1)
mod2.flow(iters = 150, track = True, step = 30)
mod2.Grapher.plotFlowData()

# %%
print("mod conductivity: ", mod.conductivity)
print("mod2 conductivity: ", mod2.conductivity)
# Out:
# mod conductivity:  0.1
# mod2 conductivity:  0.1
