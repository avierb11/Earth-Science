# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Linear Regression

# %%
def linearFit(x,y):
    '''
    This is just a simple linear fit.
    '''
    A = np.array([x,np.ones(x.size)]).T
    print(A.shape)
    return np.linalg.inv(A.T@A)@A.T@y

def surfaceLinearFit(x,y,z):
    '''
    A surface linear fit?
    '''
    A = np.array([x,np.ones(x.size)]).T
    B = np.array([y,np.ones(y.size)]).T
    C = np.array([A,B])
    print(C)
    #return np.linalg.inv(A.T@A)@A.T@z

# %% [markdown]
# # Testing

# %%
# %matplotlib inline
x = np.linspace(0,10,15)
y = 3*x

[m,b] = linearFit(x,y)
pred = m*x + b

#print(pred)

'''
plt.plot(x,y,label="Actual")
plt.plot(x,pred,label="Predicted")
plt.legend()
plt.show()
'''
# Out:
# (15, 2)
# '\nplt.plot(x,y,label="Actual")\nplt.plot(x,pred,label="Predicted")\nplt.legend()\nplt.show()\n'

# %% [markdown]
# # Define the data

# %%
x = np.linspace(0,10,10)
y = np.linspace(0,10,10)
X,Y = np.meshgrid(x,y)

Z = X + Y

# %% [markdown]
# # Creating Regression surface

# %%
Z2 = surfaceLinearFit(X,Y,Z)
# Out:
# [[array([[ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#          5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ],
#        [ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#          5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ],
#        [ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#          5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ],
#        [ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#          5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ],
#        [ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#          5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ],
#        [ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#          5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ],
#        [ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
# ...

# %% [markdown]
# # Plotting Surface

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
